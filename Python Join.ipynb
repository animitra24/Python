# %% [markdown]
# # Python Join

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:\\Users\\User\\Desktop\\Anindita Mitra\\Machine Learning\\EDA\\Fruits_Profit.csv')

# %%
df2 = pd.read_csv('C:\\Users\\User\\Desktop\\Anindita Mitra\\Machine Learning\\EDA\\Cafe _Country.csv')

# %%
display(df1)
# Out:
#    PRODUCTLINE  Country     Sex  ITEMSSOLD  SALES  Profit
# 0        Mango  Belgium    Male         30   1800     560
# 1        Mango  Belgium  Female         34   2703     400
# 2        Mango  Belgium    Male         41  12001    5642
# 3        Mango  Belgium  Female         52  19000   18000
# 4        Apple  Belgium    Male         49  27000   23000
# 5        Apple  Belgium  Female         36   3000     213
# 6        Apple  Belgium    Male         29   4000    2566
# 7        Apple  Belgium  Female         48   5000    4500
# 8       Banana  Belgium    Male         34   8000    5439
# 9       Banana  Belgium  Female         27   9000    8000
# 10      Banana  Belgium    Male         36  10000    6256
# 11      Banana  Belgium  Female         23   8000    7000
# 12      Banana  Belgium  Female         27   9000    5252

# %%
display(df2)
# Out:
#     Country  PRODUCT ID
# 0   Belgium           1
# 1   Belgium           1
# 2   Belgium           1
# 3   Belgium           1
# 4   Germany           2
# 5   Germany           2
# 6   Germany           2
# 7   Germany           3
# 8   Germany           3
# 9   Germany           3
# 10  Germany           3
# 11   France           4
# 12   France           4
# 13   France           4

# %%
df1.join(df2, how = 'left', lsuffix='Country')
# Out:
#    PRODUCTLINE CountryCountry     Sex  ITEMSSOLD  SALES  Profit  Country  \
# 0        Mango        Belgium    Male         30   1800     560  Belgium
# 1        Mango        Belgium  Female         34   2703     400  Belgium
# 2        Mango        Belgium    Male         41  12001    5642  Belgium
# 3        Mango        Belgium  Female         52  19000   18000  Belgium
# 4        Apple        Belgium    Male         49  27000   23000  Germany
# 5        Apple        Belgium  Female         36   3000     213  Germany
# 6        Apple        Belgium    Male         29   4000    2566  Germany
# 7        Apple        Belgium  Female         48   5000    4500  Germany
# 8       Banana        Belgium    Male         34   8000    5439  Germany
# 9       Banana        Belgium  Female         27   9000    8000  Germany
# 10      Banana        Belgium    Male         36  10000    6256  Germany
# 11      Banana        Belgium  Female         23   8000    7000   France
# ...

# %%
df1.join(df2, how = 'right', lsuffix='Country')
# Out:
#    PRODUCTLINE CountryCountry     Sex  ITEMSSOLD    SALES   Profit  Country  \
# 0        Mango        Belgium    Male       30.0   1800.0    560.0  Belgium
# 1        Mango        Belgium  Female       34.0   2703.0    400.0  Belgium
# 2        Mango        Belgium    Male       41.0  12001.0   5642.0  Belgium
# 3        Mango        Belgium  Female       52.0  19000.0  18000.0  Belgium
# 4        Apple        Belgium    Male       49.0  27000.0  23000.0  Germany
# 5        Apple        Belgium  Female       36.0   3000.0    213.0  Germany
# 6        Apple        Belgium    Male       29.0   4000.0   2566.0  Germany
# 7        Apple        Belgium  Female       48.0   5000.0   4500.0  Germany
# 8       Banana        Belgium    Male       34.0   8000.0   5439.0  Germany
# 9       Banana        Belgium  Female       27.0   9000.0   8000.0  Germany
# 10      Banana        Belgium    Male       36.0  10000.0   6256.0  Germany
# ...

# %%
df1.join(df2, how = 'inner', lsuffix='Country')
# Out:
#    PRODUCTLINE CountryCountry     Sex  ITEMSSOLD  SALES  Profit  Country  \
# 0        Mango        Belgium    Male         30   1800     560  Belgium
# 1        Mango        Belgium  Female         34   2703     400  Belgium
# 2        Mango        Belgium    Male         41  12001    5642  Belgium
# 3        Mango        Belgium  Female         52  19000   18000  Belgium
# 4        Apple        Belgium    Male         49  27000   23000  Germany
# 5        Apple        Belgium  Female         36   3000     213  Germany
# 6        Apple        Belgium    Male         29   4000    2566  Germany
# 7        Apple        Belgium  Female         48   5000    4500  Germany
# 8       Banana        Belgium    Male         34   8000    5439  Germany
# 9       Banana        Belgium  Female         27   9000    8000  Germany
# 10      Banana        Belgium    Male         36  10000    6256  Germany
# 11      Banana        Belgium  Female         23   8000    7000   France
# ...

# %%
df1.join(df2, how = 'outer', lsuffix='Country')
# Out:
#    PRODUCTLINE CountryCountry     Sex  ITEMSSOLD    SALES   Profit  Country  \
# 0        Mango        Belgium    Male       30.0   1800.0    560.0  Belgium
# 1        Mango        Belgium  Female       34.0   2703.0    400.0  Belgium
# 2        Mango        Belgium    Male       41.0  12001.0   5642.0  Belgium
# 3        Mango        Belgium  Female       52.0  19000.0  18000.0  Belgium
# 4        Apple        Belgium    Male       49.0  27000.0  23000.0  Germany
# 5        Apple        Belgium  Female       36.0   3000.0    213.0  Germany
# 6        Apple        Belgium    Male       29.0   4000.0   2566.0  Germany
# 7        Apple        Belgium  Female       48.0   5000.0   4500.0  Germany
# 8       Banana        Belgium    Male       34.0   8000.0   5439.0  Germany
# 9       Banana        Belgium  Female       27.0   9000.0   8000.0  Germany
# 10      Banana        Belgium    Male       36.0  10000.0   6256.0  Germany
# ...
